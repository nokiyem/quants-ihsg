# %%
import pandas as pd
# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

#df_join2.to_excel('data/learning-capital-df_join_all.xlsx') 
df1 =pd.read_csv('all_saham_scrape_quarterly1_transpose.csv')
df1
# Out:
#      Saham  Asset Turnover (Quarter)  Asset Turnover (TTM)  \
# 0     AALI                      0.15                  0.66
# 1     AALI                      0.15                  0.64
# 2     AALI                      0.17                  0.64
# 3     AALI                      0.19                  0.64
# 4     AALI                      0.14                  0.65
# ...    ...                       ...                   ...
# 2645  WIKA                      0.36                  0.00
# 2646  WIKA                      0.35                  0.00
# 2647  WIKA                      0.53                  0.00
# 2648  WIKA                      0.00                  0.00
# 2649  WIKA                      0.00                  0.00
#
#      Capital expenditure (Quarter)  Cash Conversion Cycle (Quarter)  \
# 0                             -230                            41.98
# 1                             -186                            43.24
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2650 entries, 0 to 2649
# Data columns (total 48 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Saham                                 2650 non-null   object
#  1   Asset Turnover (Quarter)              2650 non-null   float64
#  2   Asset Turnover (TTM)                  2650 non-null   float64
#  3   Capital expenditure (Quarter)         2650 non-null   object
#  4   Cash Conversion Cycle (Quarter)       2650 non-null   float64
#  5   Current Ratio (Quarter)               2650 non-null   float64
#  6   Days Inventory (Quarter)              2650 non-null   float64
#  7   Days Payables Outstanding (Quarter)   2650 non-null   float64
#  8   Days Sales Outstanding (Quarter)      2650 non-null   float64
#  9   Debt to Equity Ratio (Quarter)        2650 non-null   float64
# ...

# %%
df1['EPS (Quarter)']
# Out:
# 0        99.05
# 1        10.83
# 2       192.79
# 3        51.92
# 4        35.05
#          ...
# 2645      0.00
# 2646      0.00
# 2647      0.00
# 2648      0.00
# 2649      0.00
# Name: EPS (Quarter), Length: 2650, dtype: float64

# %% [markdown]
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# for saham in df_join2.Saham.unique():
#     df_shm = df_join2.loc[df_join2.Saham==saham].loc[ : , ['Tahun','Capitalexpenditure-Annual',
#                                                            'Workingcapital-Annual','Yearly_Ret',
#                                                            'WorkingCapitalTurnover-Annual'] ]
#     plt.title(saham)
#     sns.lineplot(x='Tahun', y='value', hue='variable',
#              data=pd.melt(df_shm, ['Tahun']))
#     plt.show()
#     #plt.plot( 'Tahun', 'Capitalexpenditure-Annual', data=df_shm, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)

# %%
plt.figure(figsize = (16,9))

# Draw line plot of size and total_bill with parameters and hue "day"
sns.lineplot(x = "Quarter", y = "Tang.ook Value Per Share (Quarter)", data = df1, hue = "Saham",
             palette = "dark", dashes = False,style="Saham")

plt.title("Line Plot", fontsize = 20)
plt.xlabel("Tahun", fontsize = 15)
plt.ylabel("Year Return", fontsize = 15)
plt.show()
